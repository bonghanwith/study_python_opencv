# %% [markdown]
# ## [Gui Features in OpenCV](https://docs.opencv.org/3.4/dc/d4d/tutorial_py_table_of_contents_gui.html)
# Here you will learn how to display and save images and videos, control mouse events and create trackbar.
#
# ### [Getting Started with Images](https://docs.opencv.org/3.4/dc/d2e/tutorial_py_image_display.html)
# Learn to load an image, display it and save it back
#
# #### Goals
# * Here, you will learn how to read an image, how to display it and how to save it back
# * You will learn these functions : [cv.imread()](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#ga288b8b3da0892bd651fce07b3bbd3a56), [cv.imshow()](https://docs.opencv.org/3.4/d7/dfc/group__highgui.html#ga453d42fe4cb60e5723281a89973ee563) , [cv.imwrite()](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#gabbc7ef1aa2edfaa87772f1202d67e0ce)
# * Optionally, you will learn how to display images with Matplotlib
# Using OpenCV
#
# #### Using OpenCV
# ##### Read an image
# Use the function [cv.imread()](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#ga288b8b3da0892bd651fce07b3bbd3a56), [cv.imshow()] to read an image. The image should be in the working directory or a full path of image should be given.
#
# Second argument is a flag which specifies the way image should be read.
#
# * [cv.IMREAD_COLOR](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#gga61d9b0126a3e57d9277ac48327799c80af660544735200cbe942eea09232eb822) : Loads a color image. Any transparency of image will be neglected. It is the default flag.
# * [cv.IMREAD_GRAYSCALE](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#gga61d9b0126a3e57d9277ac48327799c80ae29981cfc153d3b0cef5c0daeedd2125) : Loads image in grayscale mode
# * [cv.IMREAD_UNCHANGED](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#gga61d9b0126a3e57d9277ac48327799c80aeddd67043ed0df14f9d9a4e66d2b0708) : Loads image as such including alpha channel
#
# > **Note**
#     Instead of these three flags, you can simply pass integers 1, 0 or -1 respectively.
#
# See the code below:

# %%
import sys
sys.path.insert(0, '../common')
import numpy as np
import cv2 as cv
import bonghanUtil as u

fileName = '../data/messi5.jpg'
img = cv.imread(fileName, cv.IMREAD_GRAYSCALE) # 1, 0 or -1
#img = cv.imread(fileName, cv.IMREAD_COLOR  ) # 1, 0 or -1
#img = cv.imread(fineName, cv.IMREAD_UNCHANGED) # 1, 0 or -1
#cv.namedWindow('image', cv.WINDOW_NORMAL)

# %% [markdown]
# ##### Display an image
# Use the function cv.imshow() to display an image in a window. The window automatically fits to the image size.
#
# First argument is a window name which is a string. second argument is our image. You can create as many windows as you wish, but with different window names.

# %%
'''
cv.imshow('image', img)
cv.waitKey(0)
cv.destroyAllWindows()
cv.waitKey(1)
'''
u.showImage(img)

# %% [markdown]
# ![](opencv_screenshot.jpg)
#
# [cv.waitKey()](https://docs.opencv.org/3.4/d7/dfc/group__highgui.html#ga5628525ad33f52eab17feebcfba38bd7) is a keyboard binding function. Its argument is the time in milliseconds. The function waits for specified milliseconds for any keyboard event. If you press any key in that time, the program continues. If 0 is passed, it waits indefinitely for a key stroke. It can also be set to detect specific key strokes like, if key a is pressed etc which we will discuss below.
#
# > **Note** Besides binding keyboard events this function also processes many other GUI events, so you MUST use it to actually display the image.
#
# [cv.destroyAllWindows()](https://docs.opencv.org/3.4/d7/dfc/group__highgui.html#ga6b7fc1c1a8960438156912027b38f481) simply destroys all the windows we created. If you want to destroy any specific window, use the function [cv.destroyWindow()](https://docs.opencv.org/3.4/d7/dfc/group__highgui.html#ga851ccdd6961022d1d5b4c4f255dbab34) where you pass the exact window name as the argument.
#
# > **Note** There is a special case where you can already create a window and load image to it later. In that case, you can specify whether window is resizable or not. It is done with the function cv.namedWindow(). By default, the flag is cv.WINDOW_AUTOSIZE. But if you specify flag to be cv.WINDOW_NORMAL, you can resize window. It will be helpful when image is too large in dimension and adding track bar to windows.
#
# ##### Write an image
# Use the function [cv.imwrite()](https://docs.opencv.org/3.4/d4/da8/group__imgcodecs.html#gabbc7ef1aa2edfaa87772f1202d67e0ce) to save an image.
#
# First argument is the file name, second argument is the image you want to save.

# %%
img = cv.imread(fileName, cv.IMREAD_GRAYSCALE)
cv.imshow('image',img)
k = cv.waitKey(0) & 0xFF

if k == 27:         
    pass
elif k == ord('s'): 
    cv.imwrite('messigray.png',img)
    
cv.destroyAllWindows()
cv.waitKey(1)
# Out:
# -1

# %% [markdown]
# **warning**
#
# If you are using a 64-bit machine, you will have to modify k = cv.waitKey(0) line as follows : k = cv.waitKey(0) & 0xFF
#
# ![](messigray.png)
#
# #### Matplotlib 이용하기
# Matplotlib is a plotting library for Python which gives you wide variety of plotting methods. You will see them in coming articles. Here, you will learn how to display image with Matplotlib. You can zoom images, save it etc using Matplotlib.

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv.imread('../data/messi5.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#plt.xticks([100, 200, 400, 600]), plt.yticks([0, 300, 400])
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **See also**
#
# Plenty of plotting options are available in Matplotlib. Please refer to Matplotlib docs for more details. Some, we will see on the way.
#
# **warning**
#
# Color image loaded by OpenCV is in BGR mode. But Matplotlib displays in RGB mode. So color images will not be displayed correctly in Matplotlib if image is read with OpenCV. Please see the exercises for more details.
#
# #### Additional Resources
# 1. [Matplotlib Plotting Styles and Features](https://matplotlib.org/api/pyplot_api.html)
#
# #### Exercises
# 1. There is some problem when you try to load color image in OpenCV and display it in Matplotlib. Read [this discussion](https://stackoverflow.com/questions/15072736/extracting-a-region-from-an-image-using-slicing-in-python-opencv/15074748#15074748) and understand it.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv.imread('../data/messi5.jpg')
b, g, r = cv.split(img)
img2 = cv.merge([r, g, b])

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img2)
plt.show()

cv.imshow('bgr image',img) # expects true color
cv.imshow('rgb image',img2) # expects distorted color
cv.waitKey(0)
cv.destroyAllWindows()
cv.waitKey(1)
# Out:
# -1

# %%
import sys
sys.path.insert(0, '../common')
import bonghanUtil as u

img3 = img2[:, :, ::-1]
#img3 = img2[::, ::-1]
#img3 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)

u.showImage(img3)

region = img2[0:280,0:288,::-1]

u.showImage(region)
