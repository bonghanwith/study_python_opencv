# %%
import numpy as np
import cv2

img = cv2.imread('messi5.png', cv2.IMREAD_GRAYSCALE) # 1, 0 or -1
#img = cv2.imread('messi5.png', cv2.IMREAD_COLOR  ) # 1, 0 or -1
#img = cv2.imread('messi5.png', cv2.IMREAD_UNCHANGED) # 1, 0 or -1
#cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 이미지 읽기
#
# #### 문제
# 종료시 오류 발생

# %% [markdown]
# # 이미지 쓰기와 요약하기

# %%
import numpy as np
import cv2
import sys

img = cv2.imread('messi5.png', cv2.IMREAD_GRAYSCALE)
cv2.imshow('image',img)
k = cv2.waitKey(0)

if k == 27:         
    cv2.destroyAllWindows()
elif k == ord('s'): 
    cv2.imwrite('messigray.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# # Matplotlib 이용하기
# > ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('messi5.png',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([100, 200, 400, 600]), plt.yticks([100, 600])
plt.show()

# %% [markdown]
# # Matplotlib과 OpenCV 픽셀 순서가 다름
# Matplotbli RGB
# OpenCV     BGR

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('messi5.png')
b, g, r = cv2.split(img)
img2 = cv2.merge([r, g, b])

plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(img2)
plt.show()

cv2.imshow('bgr image',img) # expects true color
cv2.imshow('rgb image',img2) # expects distorted color
cv2.waitKey(0)
cv2.destroyAllWindows()
