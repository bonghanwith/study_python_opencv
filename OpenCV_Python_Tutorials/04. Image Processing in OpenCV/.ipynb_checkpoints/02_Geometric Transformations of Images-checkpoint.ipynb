# %% [markdown]
# ### [Geometric Transformations of Images](https://docs.opencv.org/3.4/da/d6e/tutorial_py_geometric_transformations.html)
# Learn to apply different geometric transformations to images like rotation, translation etc.
#
# #### Goals
# * 변환, 회전, 아핀 변환 등과 같은 이미지에 다른 기하학적 변형을 적용하는 방법을 배웁니다.
# * 다음 함수를 볼 수 있습니다 : [cv.getPerspectiveTransform](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#ga8c1ae0e3589a9d77fffc962c49b22043)
#
# #### 변환
# OpenCV는 모든 종류의 변형을 가질 수있는 두 가지 변환 함수, [cv.warpAffine](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#ga0203d9ee5fcd28d40dbc4a1ea4451983) 및 [cv.warpPerspective](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#gaf73673a7e8e18ec6963e3774e6a94b87)를 제공합니다. cv.warpPerspective는 **3x3** 변환 행렬을 입력으로 받는 반면 cv2.warpAffine 은 **2x3** 변환 행렬을 사용합니다.
#
# #### 크기조정
# 크기 조정은 이미지의 크기를 조정하는 것입니다. OpenCV는 이 목적으로 cv.resize() 함수를 제공 합니다. 이미지의 크기는 수동으로 지정하거나 배율 인수를 지정할 수 있습니다. 다른 보간 방법이 사용됩니다. 바람직한 보간 방법은 cv.INTER_AREA을 축소하고 대한 cv.INTER_CUBIC(느리게) cv.INTER_LINEAR 줌 기능. 디폴트에서는, 모든 사이즈 변경을 위해서(때문에) 사용되는 보간 법은 cv.INTER_LINEAR 입니다. 다음 방법 중 하나를 사용하여 입력 이미지의 크기를 조정할 수 있습니다.
#
# ```
# getPerspectiveTransform() [1/2]
# Mat cv::getPerspectiveTransform (const Point2f src[], const Point2f dst[] )
#
# Python:
#     retval = cv.getPerspectiveTransform(src, dst)
# returns 3x3 perspective transformation for the corresponding 4 point pairs.
# ```

# %%
import cv2 as cv
import numpy as np

img = cv.imread('../data/messi5.jpg')
res = cv.resize(img, None, fx = 2, fy = 2, interpolation = cv2.INTER_CUBIC)

#다른 방법
height, width = img.shape[:2]
res2 = cv2.resize(img, (width * 2, height * 2), interpolation = cv2.INTER_CUBIC)

# %% [markdown]
# #### Translation
# 번역은 물체의 위치를 이동시키는 것입니다. 여러분이 (x, y) 방향의 변화를 안다면, 다음과 같이 \\((t_x, t_y)\\)변환 행렬 \\( \textbf{M} \\)을 만들 수 있습니다 :
#
# $$ M = \left[\begin{array}{rr}
# 1 & 0 & t_x\\
# 0 & 1 & t_y\\
# \end{array}\right] $$
#
# np.float32 유형의 Numpy 배열 로 만들고 cv.warpAffine () 함수 로 전달할 수 있습니다. 아래 (100,50) 이동에 대한 예를 참조하십시오.

# %%
import cv2 as cv
import numpy as np

img = cv.imread('messi5.jpg', 0)
rows, cols = img.shape

M   = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, img.shape[::-1])

cv.imshow('src', img)
cv.imshow('dst', dst)

cv.waitKey(0)
cv.destroyAllWindows()
cv.waitKey(1)
# Out:
# -1

# %% [markdown]
# ##### 경고
# cv.warpAffine() 함수 의 세 번째 인수는 출력 이미지의 크기이며, 너비, 높이 형태 여야합니다. 너비 = 열 수 and 높이 = 행 수를 기억하십시오.
# ![](translation.jpg)

# %% [markdown]
# #### Rotation
# 각도의 이미지 회전은 \\(\theta\\)다음과 같은 형식의 변환 행렬에 의해 수행됩니다.
#
# $$ M = \begin{bmatrix} cos\theta & -sin\theta \\ sin\theta & cos\theta \end{bmatrix} $$
#
# 그러나 OpenCV는 조정 가능한 회전 중심으로 크기가 조정 된 회전을 제공하므로 원하는 위치에서 회전 할 수 있습니다. 수정 된 변환 행렬은에 의해 주어진다.
#
# $$ \begin{bmatrix} \alpha & \beta & (1- \alpha ) \cdot center.x - \beta \cdot center.y \\ - \beta & \alpha & \beta \cdot center.x + (1- \alpha ) \cdot center.y \end{bmatrix} $$
#
# 어디에:
#
# $$ \begin{array}{l} \alpha = scale \cdot \cos \theta , \\ \beta = scale \cdot \sin \theta \end{array} $$
#
# 이 변환 행렬을 찾기 위해 OpenCV는 [cv2.getRotationMatrix2D](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#gafbbc470ce83812914a70abfb604f4326) 함수를 제공합니다. 크기 조정 없이 **중앙을 기준**으로 이미지를 **90도 회전**시키는 아래의 예제를 확인하십시오.

# %%
Mrotation = cv.getRotationMatrix2D((cols / 2, rows / 2), 90, 1)
dst = cv.warpAffine(img, Mrotation, img.shape[::-1])

cv.imshow('src', img)
cv.imshow('dst', dst)

cv.waitKey(0)
cv.destroyAllWindows()
cv.waitKey(1)
# Out:
# -1

# %% [markdown]
# ![](rotation.jpg)
#
# #### Affine Transformation
# 아핀 변환에서 원본 이미지의 모든 평행선은 출력 이미지에서 여전히 평행합니다. 변환 행렬을 찾으려면 입력 이미지와 출력 이미지의 해당 위치에서 세 점이 필요합니다. 그런 다음 [cv.getAffineTransform]((https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#ga8f6d378f9f8eebb5cb55cd3ae295a999))은 [cv.warpAffine](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#ga0203d9ee5fcd28d40dbc4a1ea4451983)에 전달 될 2x3 행렬을 생성합니다.
#
# Check below example, and also look at the points I selected (which are marked in Green color):

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

img        = cv.imread('../data/drawing.png')
rows, cols = (380, 310)
resize     = cv.resize(img, (cols, rows), interpolation = cv.INTER_CUBIC)

pts1 = np.float32([[50,  50], [200, 50], [50 , 200]])
pts2 = np.float32([[10, 100], [200, 50], [100, 250]])

M   = cv.getAffineTransform(pts1, pts2)
dst = cv.warpAffine(resize, M, (cols, rows))

plt.subplot(121), plt.imshow(img), plt.title('Input')
plt.subplot(122), plt.imshow(dst), plt.title('Output')
plt.show()

# %% [markdown]
# #### Perspective Transformation
# 원근감 변환의 경우 3x3 변형 행렬이 필요합니다. 직선은 변환 후에도 직선으로 유지됩니다. 이 변환 행렬을 찾으려면 입력 이미지와 출력 이미지의 해당 점에 4점이 필요합니다. 이 4점 중 3점은 동일 선상이 아니어야 합니다. 그런 다음 변환 행렬은 [cv.getPerspectiveTransform](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#ga8c1ae0e3589a9d77fffc962c49b22043) 함수로 찾을 수 있습니다. 그런 다음 이 3x3 변환 행렬로 [cv.warpPerspective](https://docs.opencv.org/3.4/da/d54/group__imgproc__transform.html#gaf73673a7e8e18ec6963e3774e6a94b87)를 적용 하십시오.
#
# 아래 코드를 참조하십시오.

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

img    = cv.imread('sudokusmall.png')
resize = cv.resize(img, (420, 420), interpolation = cv.INTER_CUBIC)

pts1 = np.float32([[56, 65], [368, 52], [28, 387] ,[389 ,390]])
pts2 = np.float32([[0 , 0] , [300, 0] , [0 , 300] ,[300 ,300]])

M   = cv.getPerspectiveTransform(pts1, pts2)
dst = cv.warpPerspective(resize, M, (300,300))

plt.subplot(121),plt.imshow(resize),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %% [markdown]
# #### Additional Resources
# 1. "Computer Vision: Algorithms and Applications", Richard Szeliski
#
# #### Exercises
